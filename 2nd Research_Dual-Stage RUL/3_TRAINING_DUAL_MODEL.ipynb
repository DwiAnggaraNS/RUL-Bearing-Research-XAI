# %% [markdown]
# # Training

# %% [markdown]
# ## Konfigurasi Global

# %%
IS_USING_FFT_DOMAIN = True
WINDOW_SIZE = 128

ROOT_PROJECT_DATASET = "/home/praktikan/projects/github/DwiAnggara/ProyekRisetBearing"
BEARING_VARIATION_FOLDER = ("bearing_1", )

BEARING_LIFESPAN_TIME = 392_275
TURNING_POINT_TIME = 290000

MAIN_BEARING = BEARING_VARIATION_FOLDER[0] # Pilih bearing utama untuk analisis

# FFT Domain
# 0 - 1280 Hz
FREQUENCY_MIN, FREQUENCY_MAX = 220, 260
SAMPLING_RATE = 2560

# %%
'''
HI : BLACK - Full line
TP : RED - Full line
X : BLUE - Full Line 
Y : ORANGE - Full line 
Z : GREEN - Full line
'''

PLOT_STYLES = {
    "HI": {"color": "black", "linestyle": "-"},
    "HI_PRED": {"color": "gold", "linestyle": "--"},
    "TP": {"color": "red", "linestyle": "-"},
    "TP_PRED": {"color": "red", "linestyle": "--"},
    "X": {"color": "blue", "linestyle": "-"},
    "Y": {"color": "orange", "linestyle": "-"},
    "Z": {"color": "green", "linestyle": "-"},
}

colors_map = {
    'RAW Dual': '#1f77b4',
    'RAW Single': '#ff7f0e',
    'FFT Dual': '#2ca02c',
    'FFT Single': '#d62728'
}

# %% [markdown]
# ## Import

# %%
import os
import glob
import re
import time

import numpy as np
from numpy.fft import rfft, rfftfreq

import pandas as pd

import dask.dataframe as dd
import dask.array as da
from dask.diagnostics.progress import ProgressBar

import torch
import torch.optim as optim
import torch.nn as nn

from matplotlib import pyplot as plt
import matplotlib.pyplot as plt

import plotly.graph_objs as go
import plotly.offline as pyo

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import MinMaxScaler

import seaborn as sns

from tqdm import tqdm  # Import tqdm for progress bar

import gc

# %% [markdown]
# ## Helper Function

# %%
def temp_output_bearing_root(bearing_name: str) -> str:
    return f"{ROOT_PROJECT_DATASET}/{bearing_name}"

def bearing_file_full_parquet(bearing_name: str) -> str:
    return f"{temp_output_bearing_root(bearing_name)}/{bearing_name}_full.parquet"

def bearing_file_raw_parquet(bearing_name: str) -> str:
    return f"{temp_output_bearing_root(bearing_name)}/{bearing_name}_raw.parquet"

def export_dataset_root(bearing_name: str) -> str:
    return f"{temp_output_bearing_root(bearing_name)}/datasets"

def export_dataset_name_for_fft_base(bearing_name: str) -> str:
    return f"{export_dataset_root(bearing_name)}/fft"

def export_dataset_name_for_raw_base(bearing_name: str) -> str:
    return f"{export_dataset_root(bearing_name)}/raw"


def bearing_file_fft_parquet(bearing_name: str) -> str:
    return f"{temp_output_bearing_root(bearing_name)}/{bearing_name}_fft.parquet"

def series_health_index(t: float, Tcp: float, Tf: float) -> float:
    """Calculate the health index based on time, Tcp, and Tf.
    Args:
        t (float): current time
        Tcp (float): turning point time
        Tf (float): max time

    Returns:
        float: health index value between 0 (Broken) and 1 (Good)
    """
    return 1 - ( max((t - Tcp), 0) / (Tf - Tcp) )

def health_index_to_rul(health_index, Tf: float) -> float:
    """
    Convert health index (HI) to RUL.
    HI: 1.0 = new, 0.0 = failed
    max_rul: maximum RUL (e.g., total life in seconds or cycles)
    """
    return np.clip(health_index, 0, 1) * Tf

def create_sequences(X, y, window_size=10):
    Xs, ys = [], []
    for i in range(len(X) - window_size):
        Xs.append(X[i:(i + window_size)])
        ys.append(y[i + window_size])
    return np.array(Xs), np.array(ys)

def rmse_score(y_true, y_pred):
    """Root Mean Squared Error"""
    return np.sqrt(mean_squared_error(y_true, y_pred))

def relative_prediction_error(y_true, y_pred):
    """Relative Prediction Error (RPE) as a percentage"""
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    # Avoid division by zero
    mask = y_true != 0
    return np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100

def accuracy_score(y_true, y_pred):
    """
    Calculate the accuracy score for binary or multiclass classification.
    Args:
        y_true (array-like): Ground truth labels.
        y_pred (array-like): Predicted labels.
    Returns:
        float: Accuracy score (between 0 and 1).
    """
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)
    return np.mean(y_true == y_pred)

def precision_score(y_true, y_pred):
    """
    Calculate the precision score for binary or multiclass classification.
    Args:
        y_true (array-like): Ground truth labels.
        y_pred (array-like): Predicted labels.
    Returns:
        float: Precision score (between 0 and 1).
    """
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)
    true_positive = np.sum((y_true == 1) & (y_pred == 1))
    false_positive = np.sum((y_true == 0) & (y_pred == 1))
    return true_positive / (true_positive + false_positive) if (true_positive + false_positive) > 0 else 0.0

def recall_score(y_true, y_pred):
    """
    Calculate the recall score for binary or multiclass classification.
    Args:
        y_true (array-like): Ground truth labels.
        y_pred (array-like): Predicted labels.
    Returns:
        float: Recall score (between 0 and 1).
    """
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)
    true_positive = np.sum((y_true == 1) & (y_pred == 1))
    false_negative = np.sum((y_true == 1) & (y_pred == 0))
    return true_positive / (true_positive + false_negative) if (true_positive + false_negative) > 0 else 0.0

def f1_score(y_true, y_pred):
    """
    Calculate the F1 score for binary or multiclass classification.
    Args:
        y_true (array-like): Ground truth labels.
        y_pred (array-like): Predicted labels.
    Returns:
        float: F1 score (between 0 and 1).
    """
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    return 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0.0

def confusion_matrix(y_true, y_pred):
    """
    Calculate the confusion matrix for binary or multiclass classification.
    Args:
        y_true (array-like): Ground truth labels.
        y_pred (array-like): Predicted labels.
    Returns:
        np.ndarray: Confusion matrix.
    """
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)
    classes = np.unique(np.concatenate((y_true, y_pred)))
    matrix = np.zeros((len(classes), len(classes)), dtype=int)
    
    for i, true_label in enumerate(classes):
        for j, pred_label in enumerate(classes):
            matrix[i, j] = np.sum((y_true == true_label) & (y_pred == pred_label))
    
    return matrix

def asymmetric_loss_scoring_function(y_pred, y_true, a=10, b=13):
    """
    Asymmetric loss for regression (PyTorch version).
    Penalizes late predictions more than early ones using an exponential function.
    y = exp(-(y_pred - y_true)/a) - 1, if early (y_pred < y_true)
    y = exp((y_pred - y_true)/b) - 1, if late (y_pred >= y_true)
    """
    diff = y_pred - y_true
    loss = torch.where(
        diff < 0,
        torch.exp(-diff / a) - 1,   # Early prediction (small penalty)
        torch.exp(diff / b) - 1     # Late prediction (large penalty)
    )
    return loss.mean()

# %% [markdown]
# ## A. Load Dataset

# %%
# Load Training Dataset
if not IS_USING_FFT_DOMAIN:
    TRAIN_DATA_LOC = f"{export_dataset_name_for_raw_base(MAIN_BEARING)}_train_data.parquet"
    TEST_DATA_LOC = f"{export_dataset_name_for_raw_base(MAIN_BEARING)}_test_data.parquet"
else:
    TRAIN_DATA_LOC = f"{export_dataset_name_for_fft_base(MAIN_BEARING)}_{FREQUENCY_MIN}_{FREQUENCY_MAX}_train_data.parquet"
    TEST_DATA_LOC = f"{export_dataset_name_for_fft_base(MAIN_BEARING)}_{FREQUENCY_MIN}_{FREQUENCY_MAX}_test_data.parquet"

TRAIN_DATA = pd.read_parquet(f"{TRAIN_DATA_LOC}")
TEST_DATA = pd.read_parquet(f"{TEST_DATA_LOC}")

print(f"Train (loc: {TRAIN_DATA_LOC}) shape: ({TRAIN_DATA.shape[0]}, {TRAIN_DATA.shape[1]})")
print(f"Test (loc: {TEST_DATA_LOC}) shape: ({TEST_DATA.shape[0]}, {TEST_DATA.shape[1]})")
# Out:
# Train (loc: /home/praktikan/projects/github/DwiAnggara/ProyekRisetBearing/bearing_1/datasets/fft_220_260_train_data.parquet) shape: (653, 5)
# Test (loc: /home/praktikan/projects/github/DwiAnggara/ProyekRisetBearing/bearing_1/datasets/fft_220_260_test_data.parquet) shape: (652, 5)

# %% [markdown]
# ## B. Normalization

# %%
FEATURES = ["FFT_X", "FFT_Y", "FFT_Z"] if IS_USING_FFT_DOMAIN else ["X", "Y", "Z"]
TARGET = "health_index"

fft_scaler = MinMaxScaler()

X_train = fft_scaler.fit_transform(TRAIN_DATA[FEATURES])
y_train = TRAIN_DATA[TARGET].values

X_test = fft_scaler.transform(TEST_DATA[FEATURES])
y_test = TEST_DATA[TARGET].values

# %% [markdown]
# ## C. Create Sequences Windows

# %%
X_train_seq, y_train_seq = create_sequences(X_train, y_train, window_size=WINDOW_SIZE)
X_test_seq, y_test_seq = create_sequences(X_test, y_test, window_size=WINDOW_SIZE)

print(f"X_train_seq shape: {X_train_seq.shape}, y_train_seq shape: {y_train_seq.shape}")
print(f"X_test_seq shape: {X_test_seq.shape}, y_test_seq shape: {y_test_seq.shape}")
# Out:
# X_train_seq shape: (525, 128, 3), y_train_seq shape: (525,)
# X_test_seq shape: (524, 128, 3), y_test_seq shape: (524,)

# %% [markdown]
# ## D. Convert to Tensor

# %%
X_train_tensor = torch.from_numpy(X_train_seq).float()
y_train_tensor = torch.from_numpy(y_train_seq).float().view(-1, 1)

X_test_tensor = torch.from_numpy(X_test_seq).float()
y_test_tensor = torch.from_numpy(y_test_seq).float().view(-1, 1)

y_cp_train = (y_train_seq == 1.0).astype(float)
y_cp_train = torch.from_numpy(y_cp_train).float().view(-1, 1)

y_cp_test = (y_test_seq == 1.0).astype(float)
y_cp_test = torch.from_numpy(y_cp_test).float().view(-1, 1)

y_hi_train = (y_train_seq < 1.0).astype(float)
y_hi_train = torch.from_numpy(y_hi_train).float().view(-1, 1)

y_hi_test = (y_test_seq < 1.0).astype(float)
y_hi_test = torch.from_numpy(y_hi_test).float().view(-1, 1)

# %% [markdown]
# ## E. Plot Data before Training for Visualization

# %%
def plot_data_with_health_index(data, title="Data with Health Index"):
    fig, ax1 = plt.subplots(figsize=(12, 6))
    # Plot FFT features on the primary y-axis
    ax1.plot(data.index, data[FEATURES[0]], label=FEATURES[0], alpha=0.5, **PLOT_STYLES["X"])
    ax1.plot(data.index, data[FEATURES[1]], label=FEATURES[1], alpha=0.5, **PLOT_STYLES["Y"])
    ax1.plot(data.index, data[FEATURES[2]], label=FEATURES[2], alpha=0.5, **PLOT_STYLES["Z"])
    ax1.set_xlabel("Time")
    ax1.set_ylabel("FFT Amplitude")
    ax1.legend(loc="upper left")

    # Plot Health Index on the secondary y-axis
    ax2 = ax1.twinx()
    ax2.scatter(data.index, data[TARGET], label='Health Index', s=10, **PLOT_STYLES["HI"])
    ax2.set_ylabel("Health Index", color=PLOT_STYLES["HI"]["color"])
    ax2.tick_params(axis='y', labelcolor=PLOT_STYLES["HI"]["color"])

    # Combine legends
    lines_1, labels_1 = ax1.get_legend_handles_labels()
    lines_2, labels_2 = ax2.get_legend_handles_labels()
    ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc="upper right")

    plt.title(title)
    plt.tight_layout()
    plt.show()

plot_data_with_health_index(TRAIN_DATA, title="Training Data with Health Index")
plot_data_with_health_index(TEST_DATA, title="Testing Data with Health Index")

# %% [markdown]
# ## F. Define Model

# %% [markdown]
# ### 1. CPD Model

# %%
class ChangePointLSTM(nn.Module):
    """
    LSTM Model 1: Detects the change point from normal operation to degradation.
    This is a binary classification model.
    """
    def __init__(self, input_size=3, hidden_layer_size=50, num_layers=1, output_size=1, dropout_rate=0.2):
        super().__init__()
        self.lstm = nn.LSTM(input_size, hidden_layer_size, num_layers, batch_first=True)
        self.dropout = nn.Dropout(dropout_rate)
        self.linear = nn.Linear(hidden_layer_size, output_size)
        self.sigmoid = nn.Sigmoid()

    def forward(self, input_seq):
        lstm_out, _ = self.lstm(input_seq)
        last_time_step_out = lstm_out[:, -1, :]
        dropped = self.dropout(last_time_step_out)
        linear_out = self.linear(dropped)
        predictions = self.sigmoid(linear_out)
        return predictions

# %% [markdown]
# ### 2. HI Model

# %%
class HealthIndexLSTM(nn.Module):
    """
    LSTM Model 2: Predicts the Health Index (HI) after the change point.
    This is a regression model.
    """
    def __init__(self, input_size=3, hidden_layer_size=50, num_layers=2, output_size=1, dropout_rate=0.2):
        super().__init__()
        # Using 2 layers as suggested in the paper for the HI model
        self.lstm = nn.LSTM(input_size, hidden_layer_size, num_layers, batch_first=True)
        self.dropout = nn.Dropout(dropout_rate)
        self.linear = nn.Linear(hidden_layer_size, output_size)

    def forward(self, input_seq):
        lstm_out, _ = self.lstm(input_seq)
        last_time_step_out = lstm_out[:, -1, :]
        dropped = self.dropout(last_time_step_out)
        predictions = self.linear(dropped)
        return predictions

# %% [markdown]
# ## G. Training

# %% [markdown]
# ### 1. Configuration

# %%
# Hyperparameters Configuration

EPOCHS = 2000 # Number of epochs for training
PATIENCE = 150 # Early stopping patience

# Change Point Model
CPD_THRESHOLD = 0.85 
CHANGE_POINT_HIDDEN_LAYER_SIZE = 24
CHANGE_POINT_NUM_LAYERS = 1

CHANGE_POINT_DROPOUT_RATE = 0.1
CHANGE_POINT_LEARNING_RATE = 0.002
CHANGE_POINT_BETAS = (0.9, 0.999)  # Adam optimizer parameters, Only edit the second value
CHANGE_POINT_EPSILON = 1e-8  # Adam optimizer epsilon

# Health Index Model
HEALTH_INDEX_HIDDEN_LAYER_SIZE = 26
HEALTH_INDEX_NUM_LAYERS = 2

HEALTH_INDEX_DROPOUT_RATE = 0.1
HEALTH_INDEX_LEARNING_RATE = 0.001
HEALTH_INDEX_BETAS = (0.9, 0.999)  # Adam optimizer parameters, Only edit the second value
HEALTH_INDEX_EPSILON = 1e-8  # Adam optimizer epsilon

# Training strategy parameters
USE_DYNAMIC_CPD = True  # Set to False to use only ground truth
WARMUP_EPOCHS = 0  # Use ground truth for first N epochs
TRANSITION_EPOCHS = 0  # Gradual transition period
CPD_CONFIDENCE_THRESHOLD = 0.7  # Minimum confidence to use CPD prediction


_func = export_dataset_name_for_fft_base if IS_USING_FFT_DOMAIN else export_dataset_name_for_raw_base

# %% [markdown]
# ### 2. Training

# %%
cp_model = ChangePointLSTM(input_size=3, hidden_layer_size=CHANGE_POINT_HIDDEN_LAYER_SIZE, num_layers=CHANGE_POINT_NUM_LAYERS, dropout_rate=CHANGE_POINT_DROPOUT_RATE)
hi_model = HealthIndexLSTM(input_size=3, hidden_layer_size=HEALTH_INDEX_HIDDEN_LAYER_SIZE, num_layers=HEALTH_INDEX_NUM_LAYERS, dropout_rate=HEALTH_INDEX_DROPOUT_RATE)

# Define optimizers
cp_optimizer = optim.Adam(cp_model.parameters(), lr=CHANGE_POINT_LEARNING_RATE, betas=CHANGE_POINT_BETAS, eps=CHANGE_POINT_EPSILON)
hi_optimizer = optim.Adam(hi_model.parameters(), lr=HEALTH_INDEX_LEARNING_RATE, betas=HEALTH_INDEX_BETAS, eps=HEALTH_INDEX_EPSILON)

cp_loss_function = nn.BCELoss()
# hi_loss_function = nn.MSELoss()
hi_loss_function = lambda y_pred, y_true: asymmetric_loss_scoring_function(y_pred, y_true)

epochs = EPOCHS

best_hi_loss = float('inf')
best_cp_f1 = 0.0
patience = PATIENCE
wait = 0

# Save best model weights
best_hi_model_state = None
best_cp_model_state = None

# Initialize training log
training_log = {
    'epoch': [],
    'cp_loss': [],
    'hi_loss': [],
    'cp_f1': [],
    'cp_accuracy': [],
    'hi_rmse': [],
    'hi_rpe': [],
    'turning_point_gt': [],
    'turning_point_used': [],
    'turning_point_predicted': [],
    'best_hi_loss': [],
    'best_cp_f1': [],
    'wait_counter': []
}

# Find turning point index (first time HI < 1.0) - GROUND TRUTH
train_turning_point_idx_gt = np.argmax(y_train_seq < 1.0) if np.any(y_train_seq < 1.0) else len(y_train_seq)
print(f"Ground truth training turning point index: {train_turning_point_idx_gt}")

# --- TRAINING LOOP ---
start_time = time.time()
for epoch in range(epochs):
    # --- Determine which turning point to use for HI training ---
    train_turning_point_idx_pred = len(y_train_seq)  # Default
    
    if USE_DYNAMIC_CPD and epoch >= WARMUP_EPOCHS:
        # Get current CPD predictions
        cp_model.eval()
        with torch.no_grad():
            y_pred_cp_current = cp_model(X_train_tensor).cpu().numpy().flatten()
        
        # Find predicted turning point (first index where confidence > threshold)
        confident_degraded = np.where(y_pred_cp_current > CPD_CONFIDENCE_THRESHOLD)[0]
        if len(confident_degraded) > 0:
            train_turning_point_idx_pred = confident_degraded[0]
        else:
            train_turning_point_idx_pred = len(y_train_seq)
        
        # Transition strategy: gradually shift from ground truth to predictions
        if epoch < WARMUP_EPOCHS + TRANSITION_EPOCHS:
            # Linear interpolation between ground truth and prediction
            transition_factor = (epoch - WARMUP_EPOCHS) / TRANSITION_EPOCHS
            train_turning_point_idx = int(
                (1 - transition_factor) * train_turning_point_idx_gt + 
                transition_factor * train_turning_point_idx_pred
            )
        else:
            # Use CPD prediction with fallback to ground truth if unreasonable
            if train_turning_point_idx_pred < len(y_train_seq) * 0.9:  # Sanity check
                train_turning_point_idx = train_turning_point_idx_pred
            else:
                train_turning_point_idx = train_turning_point_idx_gt
    else:
        # Use ground truth turning point
        train_turning_point_idx = train_turning_point_idx_gt

    # --- Change Point Detection Training ---
    cp_model.train()
    cp_optimizer.zero_grad()
    y_pred_cp = cp_model(X_train_tensor)
    
    # CPD ground truth: always use ground truth for CPD training
    y_cp_train_binary = np.zeros(len(y_train_seq))
    if train_turning_point_idx_gt < len(y_train_seq):
        y_cp_train_binary[train_turning_point_idx_gt:] = 1
    y_cp_train_tensor = torch.from_numpy(y_cp_train_binary).float().view(-1, 1)
    
    loss_cp = cp_loss_function(y_pred_cp, y_cp_train_tensor)
    loss_cp.backward()
    cp_optimizer.step()

    # --- Health Index Prediction Training ---
    hi_model.train()
    hi_optimizer.zero_grad()
    
    # Use dynamic turning point for HI training
    if train_turning_point_idx < len(y_train_seq):
        X_train_degraded = X_train_tensor[train_turning_point_idx:]
        y_train_degraded = y_train_tensor[train_turning_point_idx:]
        
        if len(X_train_degraded) > 0:
            y_pred_hi = hi_model(X_train_degraded)
            loss_hi = hi_loss_function(y_pred_hi, y_train_degraded)
            loss_hi.backward()
        else:
            loss_hi = torch.tensor(0.0)
    else:
        loss_hi = torch.tensor(0.0)
    
    hi_optimizer.step()

    # Evaluate and log every 5 epochs
    if (epoch + 1) % 5 == 0:
        cp_model.eval()
        hi_model.eval()
        with torch.no_grad():
            # Evaluate CPD (always use ground truth for evaluation)
            y_pred_cp_train = cp_model(X_train_tensor).cpu().numpy().flatten()
            train_cp_pred = (y_pred_cp_train > 0.5).astype(int)
            train_cp_f1 = f1_score(y_cp_train_binary, train_cp_pred)
            train_cp_acc = accuracy_score(y_cp_train_binary, train_cp_pred)
            
            # Evaluate HI (use current training turning point)
            if train_turning_point_idx < len(y_train_seq) and len(X_train_degraded) > 0:
                y_pred_hi_train = hi_model(X_train_degraded).cpu().numpy().flatten()
                y_true_hi_train = y_train_degraded.cpu().numpy().flatten()
                rmse_train = rmse_score(y_true_hi_train, y_pred_hi_train)
                rpe_train = relative_prediction_error(y_true_hi_train, y_pred_hi_train)
            else:
                rmse_train = 0.0
                rpe_train = 0.0

        # Log metrics
        training_log['epoch'].append(epoch + 1)
        training_log['cp_loss'].append(loss_cp.item())
        training_log['hi_loss'].append(loss_hi.item())
        training_log['cp_f1'].append(train_cp_f1)
        training_log['cp_accuracy'].append(train_cp_acc)
        training_log['hi_rmse'].append(rmse_train)
        training_log['hi_rpe'].append(rpe_train)
        training_log['turning_point_gt'].append(train_turning_point_idx_gt)
        training_log['turning_point_used'].append(train_turning_point_idx)
        training_log['turning_point_predicted'].append(train_turning_point_idx_pred)
        training_log['best_hi_loss'].append(best_hi_loss)
        training_log['best_cp_f1'].append(best_cp_f1)
        training_log['wait_counter'].append(wait)

        # Show which turning point is being used
        turning_point_info = f"(GT: {train_turning_point_idx_gt}, Used: {train_turning_point_idx})"
        print(f"Epoch {epoch+1}/{epochs} | TP {turning_point_info} | CP Loss: {loss_cp.item():.6f} | CPD F1: {train_cp_f1:.4f} | CPD Acc: {train_cp_acc:.4f} | HI Loss: {loss_hi.item():.6f} | HI RMSE: {rmse_train:.4f} | HI RPE: {rpe_train:.2f}%")

        # Save best models
        model_improved = False
        
        # Save best HI model
        if train_turning_point_idx < len(y_train_seq) and loss_hi.item() < best_hi_loss:
            best_hi_loss = loss_hi.item()
            best_hi_model_state = hi_model.state_dict()
            model_improved = True

        # Save best CPD model
        if train_cp_f1 > best_cp_f1:
            best_cp_f1 = train_cp_f1
            best_cp_model_state = cp_model.state_dict()
            model_improved = True

        # Early stopping
        if model_improved:
            wait = 0
        else:
            wait += 1

        if wait >= patience:
            print(f"Early stopping at epoch {epoch+1} (no improvement in {patience} epochs)")
            break
        
end_time = time.time()
elapsed_time = end_time - start_time

print(f"===================\n\nTime elapsed : \n{elapsed_time:.4f}\n\n===================")

# Restore best model weights
if best_hi_model_state is not None:
    hi_model.load_state_dict(best_hi_model_state)
if best_cp_model_state is not None:
    cp_model.load_state_dict(best_cp_model_state)

print(f"Training completed. Best CPD F1: {best_cp_f1:.4f}, Best HI Loss: {best_hi_loss:.6f}")
print(f"Training strategy: {'Dynamic CPD' if USE_DYNAMIC_CPD else 'Fixed Ground Truth'}")

# Save training log to CSV
training_log_df = pd.DataFrame(training_log)
log_filename = f"{_func(MAIN_BEARING)}_dual_model_training_log.csv"
training_log_df.to_csv(log_filename, index=False)
print(f"Training log saved to: {log_filename}")

# Save model weights
cp_model_path = f"{_func(MAIN_BEARING)}_dual_lstm_cp_model_best.pth"
hi_model_path = f"{_func(MAIN_BEARING)}_dual_lstm_hi_model_best.pth"
torch.save(cp_model.state_dict(), cp_model_path)
torch.save(hi_model.state_dict(), hi_model_path)
print(f"Models saved to: {cp_model_path} and {hi_model_path}")
# Out:
# Ground truth training turning point index: 355
# Epoch 5/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.689992 | CPD F1: 0.0000 | CPD Acc: 0.6762 | HI Loss: 0.050113 | HI RMSE: 0.5519 | HI RPE: 90.99%
# Epoch 10/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.672237 | CPD F1: 0.0000 | CPD Acc: 0.6762 | HI Loss: 0.042964 | HI RMSE: 0.4857 | HI RPE: 94.95%
# Epoch 15/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.654871 | CPD F1: 0.0000 | CPD Acc: 0.6762 | HI Loss: 0.035279 | HI RMSE: 0.4080 | HI RPE: 116.00%
# Epoch 20/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.635409 | CPD F1: 0.0000 | CPD Acc: 0.6762 | HI Loss: 0.027474 | HI RMSE: 0.3207 | HI RPE: 162.74%
# Epoch 25/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.618659 | CPD F1: 0.0000 | CPD Acc: 0.6762 | HI Loss: 0.022453 | HI RMSE: 0.2939 | HI RPE: 250.91%
# Epoch 30/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.600034 | CPD F1: 0.0000 | CPD Acc: 0.6762 | HI Loss: 0.024120 | HI RMSE: 0.3418 | HI RPE: 308.48%
# Epoch 35/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.556829 | CPD F1: 0.0000 | CPD Acc: 0.6762 | HI Loss: 0.022936 | HI RMSE: 0.3031 | HI RPE: 267.84%
# Epoch 40/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.475345 | CPD F1: 0.0000 | CPD Acc: 0.6762 | HI Loss: 0.022019 | HI RMSE: 0.2821 | HI RPE: 225.25%
# Epoch 45/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.390497 | CPD F1: 0.0000 | CPD Acc: 0.6762 | HI Loss: 0.022662 | HI RMSE: 0.2802 | HI RPE: 210.57%
# Epoch 50/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.351721 | CPD F1: 0.9375 | CPD Acc: 0.9619 | HI Loss: 0.022306 | HI RMSE: 0.2782 | HI RPE: 216.86%
# Epoch 55/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.643139 | CPD F1: 0.5470 | CPD Acc: 0.7981 | HI Loss: 0.022225 | HI RMSE: 0.2798 | HI RPE: 232.19%
# Epoch 60/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.647267 | CPD F1: 0.5088 | CPD Acc: 0.7867 | HI Loss: 0.021718 | HI RMSE: 0.2814 | HI RPE: 238.77%
# Epoch 65/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.619270 | CPD F1: 0.4956 | CPD Acc: 0.7829 | HI Loss: 0.020791 | HI RMSE: 0.2762 | HI RPE: 231.25%
# Epoch 70/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.572176 | CPD F1: 0.5022 | CPD Acc: 0.7848 | HI Loss: 0.020821 | HI RMSE: 0.2684 | HI RPE: 217.76%
# Epoch 75/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.536086 | CPD F1: 0.5153 | CPD Acc: 0.7886 | HI Loss: 0.021365 | HI RMSE: 0.2614 | HI RPE: 207.79%
# Epoch 80/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.459292 | CPD F1: 0.7019 | CPD Acc: 0.8495 | HI Loss: 0.020677 | HI RMSE: 0.2551 | HI RPE: 203.54%
# Epoch 85/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.448269 | CPD F1: 0.7101 | CPD Acc: 0.8476 | HI Loss: 0.019687 | HI RMSE: 0.2403 | HI RPE: 181.85%
# Epoch 90/2000 | TP (GT: 355, Used: 400) | CP Loss: 0.445098 | CPD F1: 0.7085 | CPD Acc: 0.8495 | HI Loss: 0.012898 | HI RMSE: 0.1698 | HI RPE: 121.37%
# Epoch 95/2000 | TP (GT: 355, Used: 402) | CP Loss: 0.444426 | CPD F1: 0.6822 | CPD Acc: 0.8438 | HI Loss: 0.013138 | HI RMSE: 0.1763 | HI RPE: 87.18%
# Epoch 100/2000 | TP (GT: 355, Used: 403) | CP Loss: 0.439466 | CPD F1: 0.6719 | CPD Acc: 0.8400 | HI Loss: 0.011422 | HI RMSE: 0.1482 | HI RPE: 118.07%
# Epoch 105/2000 | TP (GT: 355, Used: 402) | CP Loss: 0.413984 | CPD F1: 0.6996 | CPD Acc: 0.8495 | HI Loss: 0.010434 | HI RMSE: 0.1448 | HI RPE: 73.56%
# Epoch 110/2000 | TP (GT: 355, Used: 399) | CP Loss: 0.378173 | CPD F1: 0.7306 | CPD Acc: 0.8610 | HI Loss: 0.011010 | HI RMSE: 0.1538 | HI RPE: 65.23%
# Epoch 115/2000 | TP (GT: 355, Used: 76) | CP Loss: 0.343964 | CPD F1: 0.9240 | CPD Acc: 0.9505 | HI Loss: 0.035216 | HI RMSE: 0.3531 | HI RPE: 78.55%
# Epoch 120/2000 | TP (GT: 355, Used: 397) | CP Loss: 0.266626 | CPD F1: 0.9245 | CPD Acc: 0.9543 | HI Loss: 0.020434 | HI RMSE: 0.2388 | HI RPE: 171.23%
# Epoch 125/2000 | TP (GT: 355, Used: 77) | CP Loss: 0.251207 | CPD F1: 0.9140 | CPD Acc: 0.9390 | HI Loss: 0.041331 | HI RMSE: 0.4507 | HI RPE: 62.86%
# Epoch 130/2000 | TP (GT: 355, Used: 382) | CP Loss: 0.198516 | CPD F1: 0.9022 | CPD Acc: 0.9410 | HI Loss: 0.015423 | HI RMSE: 0.2107 | HI RPE: 131.86%
# Epoch 135/2000 | TP (GT: 355, Used: 386) | CP Loss: 0.175214 | CPD F1: 0.9274 | CPD Acc: 0.9562 | HI Loss: 0.014271 | HI RMSE: 0.1841 | HI RPE: 75.21%
# Epoch 140/2000 | TP (GT: 355, Used: 371) | CP Loss: 0.132599 | CPD F1: 0.9728 | CPD Acc: 0.9829 | HI Loss: 0.015131 | HI RMSE: 0.1949 | HI RPE: 51.85%
# Epoch 145/2000 | TP (GT: 355, Used: 360) | CP Loss: 0.118737 | CPD F1: 0.9941 | CPD Acc: 0.9962 | HI Loss: 0.014481 | HI RMSE: 0.1919 | HI RPE: 88.69%
# Epoch 150/2000 | TP (GT: 355, Used: 366) | CP Loss: 0.092162 | CPD F1: 0.9672 | CPD Acc: 0.9790 | HI Loss: 0.014673 | HI RMSE: 0.1969 | HI RPE: 89.43%
# Epoch 155/2000 | TP (GT: 355, Used: 368) | CP Loss: 0.084490 | CPD F1: 0.9728 | CPD Acc: 0.9829 | HI Loss: 0.013384 | HI RMSE: 0.1944 | HI RPE: 60.92%
# Epoch 160/2000 | TP (GT: 355, Used: 360) | CP Loss: 0.068041 | CPD F1: 0.9913 | CPD Acc: 0.9943 | HI Loss: 0.013673 | HI RMSE: 0.1784 | HI RPE: 53.29%
# Epoch 165/2000 | TP (GT: 355, Used: 363) | CP Loss: 0.060206 | CPD F1: 0.9851 | CPD Acc: 0.9905 | HI Loss: 0.012289 | HI RMSE: 0.1780 | HI RPE: 59.21%
# Epoch 170/2000 | TP (GT: 355, Used: 363) | CP Loss: 0.055246 | CPD F1: 0.9728 | CPD Acc: 0.9829 | HI Loss: 0.010827 | HI RMSE: 0.1452 | HI RPE: 50.70%
# Epoch 175/2000 | TP (GT: 355, Used: 367) | CP Loss: 0.061884 | CPD F1: 0.9790 | CPD Acc: 0.9867 | HI Loss: 0.008588 | HI RMSE: 0.1107 | HI RPE: 41.55%
# Epoch 180/2000 | TP (GT: 355, Used: 360) | CP Loss: 0.042905 | CPD F1: 0.9820 | CPD Acc: 0.9886 | HI Loss: 0.007705 | HI RMSE: 0.0931 | HI RPE: 37.48%
# Epoch 185/2000 | TP (GT: 355, Used: 367) | CP Loss: 0.056418 | CPD F1: 0.9759 | CPD Acc: 0.9848 | HI Loss: 0.006620 | HI RMSE: 0.0682 | HI RPE: 49.87%
# Epoch 190/2000 | TP (GT: 355, Used: 359) | CP Loss: 0.039939 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.004764 | HI RMSE: 0.0447 | HI RPE: 32.24%
# Epoch 195/2000 | TP (GT: 355, Used: 357) | CP Loss: 0.039154 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.004814 | HI RMSE: 0.0473 | HI RPE: 36.87%
# Epoch 200/2000 | TP (GT: 355, Used: 360) | CP Loss: 0.032195 | CPD F1: 0.9881 | CPD Acc: 0.9924 | HI Loss: 0.004251 | HI RMSE: 0.0501 | HI RPE: 50.07%
# Epoch 205/2000 | TP (GT: 355, Used: 360) | CP Loss: 0.028515 | CPD F1: 0.9941 | CPD Acc: 0.9962 | HI Loss: 0.004333 | HI RMSE: 0.0481 | HI RPE: 46.40%
# Epoch 210/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.026787 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.004031 | HI RMSE: 0.0381 | HI RPE: 42.04%
# Epoch 215/2000 | TP (GT: 355, Used: 358) | CP Loss: 0.022512 | CPD F1: 0.9941 | CPD Acc: 0.9962 | HI Loss: 0.004210 | HI RMSE: 0.0325 | HI RPE: 41.37%
# Epoch 220/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.020479 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.004139 | HI RMSE: 0.0314 | HI RPE: 36.20%
# Epoch 225/2000 | TP (GT: 355, Used: 358) | CP Loss: 0.019662 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.003772 | HI RMSE: 0.0313 | HI RPE: 34.87%
# Epoch 230/2000 | TP (GT: 355, Used: 357) | CP Loss: 0.016190 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.004372 | HI RMSE: 0.0323 | HI RPE: 38.21%
# Epoch 235/2000 | TP (GT: 355, Used: 358) | CP Loss: 0.017058 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.003889 | HI RMSE: 0.0347 | HI RPE: 39.88%
# Epoch 240/2000 | TP (GT: 355, Used: 115) | CP Loss: 0.040505 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.011762 | HI RMSE: 0.1307 | HI RPE: 23.91%
# Epoch 245/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.015065 | CPD F1: 0.9506 | CPD Acc: 0.9695 | HI Loss: 0.004427 | HI RMSE: 0.0417 | HI RPE: 41.16%
# Epoch 250/2000 | TP (GT: 355, Used: 357) | CP Loss: 0.016381 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.004268 | HI RMSE: 0.0372 | HI RPE: 41.37%
# Epoch 255/2000 | TP (GT: 355, Used: 357) | CP Loss: 0.015434 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.004002 | HI RMSE: 0.0295 | HI RPE: 31.17%
# Epoch 260/2000 | TP (GT: 355, Used: 357) | CP Loss: 0.014896 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.004241 | HI RMSE: 0.0275 | HI RPE: 27.49%
# Epoch 265/2000 | TP (GT: 355, Used: 357) | CP Loss: 0.013857 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.003660 | HI RMSE: 0.0302 | HI RPE: 32.77%
# Epoch 270/2000 | TP (GT: 355, Used: 357) | CP Loss: 0.013851 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.004107 | HI RMSE: 0.0285 | HI RPE: 36.94%
# Epoch 275/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.013401 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.003732 | HI RMSE: 0.0432 | HI RPE: 41.19%
# Epoch 280/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.012680 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.003815 | HI RMSE: 0.0279 | HI RPE: 36.31%
# Epoch 285/2000 | TP (GT: 355, Used: 357) | CP Loss: 0.012395 | CPD F1: 0.9913 | CPD Acc: 0.9943 | HI Loss: 0.003752 | HI RMSE: 0.0277 | HI RPE: 34.21%
# Epoch 290/2000 | TP (GT: 355, Used: 358) | CP Loss: 0.015315 | CPD F1: 0.9913 | CPD Acc: 0.9943 | HI Loss: 0.003873 | HI RMSE: 0.0318 | HI RPE: 37.42%
# Epoch 295/2000 | TP (GT: 355, Used: 359) | CP Loss: 0.016239 | CPD F1: 0.9911 | CPD Acc: 0.9943 | HI Loss: 0.003893 | HI RMSE: 0.0307 | HI RPE: 40.12%
# Epoch 300/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.014018 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.003827 | HI RMSE: 0.0278 | HI RPE: 34.86%
# Epoch 305/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.013725 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003912 | HI RMSE: 0.0258 | HI RPE: 31.81%
# Epoch 310/2000 | TP (GT: 355, Used: 358) | CP Loss: 0.013389 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.003328 | HI RMSE: 0.0308 | HI RPE: 36.69%
# Epoch 315/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.013151 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.004368 | HI RMSE: 0.0487 | HI RPE: 42.87%
# Epoch 320/2000 | TP (GT: 355, Used: 357) | CP Loss: 0.012015 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.004588 | HI RMSE: 0.0265 | HI RPE: 35.15%
# Epoch 325/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.011206 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003868 | HI RMSE: 0.0325 | HI RPE: 36.67%
# Epoch 330/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.010243 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003467 | HI RMSE: 0.0387 | HI RPE: 36.29%
# Epoch 335/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.009603 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003608 | HI RMSE: 0.0307 | HI RPE: 34.98%
# Epoch 340/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.009269 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003679 | HI RMSE: 0.0282 | HI RPE: 35.68%
# Epoch 345/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.008504 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003461 | HI RMSE: 0.0257 | HI RPE: 33.65%
# Epoch 350/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.008248 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003639 | HI RMSE: 0.0263 | HI RPE: 33.55%
# Epoch 355/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.007464 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003959 | HI RMSE: 0.0254 | HI RPE: 33.25%
# Epoch 360/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.007928 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003513 | HI RMSE: 0.0310 | HI RPE: 36.50%
# Epoch 365/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.007098 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.003668 | HI RMSE: 0.0417 | HI RPE: 39.53%
# Epoch 370/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.007390 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.004070 | HI RMSE: 0.0374 | HI RPE: 36.31%
# Epoch 375/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.006913 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.004866 | HI RMSE: 0.0319 | HI RPE: 36.98%
# Epoch 380/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.007180 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.004648 | HI RMSE: 0.0393 | HI RPE: 40.13%
# Epoch 385/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.006723 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.004853 | HI RMSE: 0.0491 | HI RPE: 40.51%
# Epoch 390/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.007378 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.004450 | HI RMSE: 0.0435 | HI RPE: 39.76%
# Epoch 395/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.007309 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003281 | HI RMSE: 0.0344 | HI RPE: 37.58%
# Epoch 400/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.006343 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003263 | HI RMSE: 0.0325 | HI RPE: 33.62%
# Epoch 405/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.006493 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003896 | HI RMSE: 0.0243 | HI RPE: 30.61%
# Epoch 410/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.006537 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.003016 | HI RMSE: 0.0262 | HI RPE: 32.39%
# Epoch 415/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.005857 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003173 | HI RMSE: 0.0262 | HI RPE: 33.82%
# Epoch 420/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.006538 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003149 | HI RMSE: 0.0276 | HI RPE: 32.88%
# Epoch 425/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.006437 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003540 | HI RMSE: 0.0249 | HI RPE: 32.03%
# Epoch 430/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.006481 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003815 | HI RMSE: 0.0293 | HI RPE: 33.84%
# Epoch 435/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.005299 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003122 | HI RMSE: 0.0250 | HI RPE: 31.57%
# Epoch 440/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.005203 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003107 | HI RMSE: 0.0280 | HI RPE: 32.20%
# Epoch 445/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.005730 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003542 | HI RMSE: 0.0325 | HI RPE: 33.85%
# Epoch 450/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.005602 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003303 | HI RMSE: 0.0302 | HI RPE: 34.94%
# Epoch 455/2000 | TP (GT: 355, Used: 354) | CP Loss: 0.008080 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.003323 | HI RMSE: 0.0301 | HI RPE: 35.46%
# Epoch 460/2000 | TP (GT: 355, Used: 353) | CP Loss: 0.011936 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.003568 | HI RMSE: 0.0271 | HI RPE: 31.85%
# Epoch 465/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.006005 | CPD F1: 0.9942 | CPD Acc: 0.9962 | HI Loss: 0.003623 | HI RMSE: 0.0262 | HI RPE: 31.48%
# Epoch 470/2000 | TP (GT: 355, Used: 357) | CP Loss: 0.008077 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.003252 | HI RMSE: 0.0314 | HI RPE: 31.67%
# Epoch 475/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.007248 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.003109 | HI RMSE: 0.0311 | HI RPE: 32.62%
# Epoch 480/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.006251 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003634 | HI RMSE: 0.0281 | HI RPE: 30.30%
# Epoch 485/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.005547 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003273 | HI RMSE: 0.0241 | HI RPE: 31.40%
# Epoch 490/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.005322 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003137 | HI RMSE: 0.0259 | HI RPE: 32.15%
# Epoch 495/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.005745 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003097 | HI RMSE: 0.0322 | HI RPE: 33.27%
# Epoch 500/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.005051 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003537 | HI RMSE: 0.0249 | HI RPE: 32.14%
# Epoch 505/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.004970 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003187 | HI RMSE: 0.0329 | HI RPE: 35.07%
# Epoch 510/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.004960 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003197 | HI RMSE: 0.0266 | HI RPE: 30.27%
# Epoch 515/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.004594 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003154 | HI RMSE: 0.0241 | HI RPE: 29.60%
# Epoch 520/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.004486 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003400 | HI RMSE: 0.0238 | HI RPE: 30.26%
# Epoch 525/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.004410 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003376 | HI RMSE: 0.0230 | HI RPE: 28.83%
# Epoch 530/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.005131 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003690 | HI RMSE: 0.0234 | HI RPE: 30.00%
# Epoch 535/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.004383 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003047 | HI RMSE: 0.0279 | HI RPE: 32.06%
# Epoch 540/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.004017 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003166 | HI RMSE: 0.0253 | HI RPE: 29.04%
# Epoch 545/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.004888 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003366 | HI RMSE: 0.0263 | HI RPE: 32.32%
# Epoch 550/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.004486 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002859 | HI RMSE: 0.0229 | HI RPE: 28.93%
# Epoch 555/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.004067 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.003385 | HI RMSE: 0.0247 | HI RPE: 29.55%
# Epoch 560/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.003837 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.003180 | HI RMSE: 0.0229 | HI RPE: 29.18%
# Epoch 565/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.003348 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002863 | HI RMSE: 0.0221 | HI RPE: 27.20%
# Epoch 570/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.004256 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.003059 | HI RMSE: 0.0274 | HI RPE: 31.25%
# Epoch 575/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.004916 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003267 | HI RMSE: 0.0244 | HI RPE: 29.62%
# Epoch 580/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.005138 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003017 | HI RMSE: 0.0274 | HI RPE: 29.75%
# Epoch 585/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.003517 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.003197 | HI RMSE: 0.0261 | HI RPE: 28.79%
# Epoch 590/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.004163 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003552 | HI RMSE: 0.0223 | HI RPE: 24.76%
# Epoch 595/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.003867 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002805 | HI RMSE: 0.0244 | HI RPE: 29.42%
# Epoch 600/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.003576 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.003176 | HI RMSE: 0.0248 | HI RPE: 28.14%
# Epoch 605/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.003921 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003210 | HI RMSE: 0.0227 | HI RPE: 27.89%
# Epoch 610/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.003256 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003191 | HI RMSE: 0.0229 | HI RPE: 27.30%
# Epoch 615/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.003784 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003133 | HI RMSE: 0.0223 | HI RPE: 24.90%
# Epoch 620/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.003036 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003139 | HI RMSE: 0.0219 | HI RPE: 27.47%
# Epoch 625/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.003434 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002715 | HI RMSE: 0.0208 | HI RPE: 26.02%
# Epoch 630/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.003530 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003111 | HI RMSE: 0.0204 | HI RPE: 24.14%
# Epoch 635/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.003367 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003055 | HI RMSE: 0.0242 | HI RPE: 26.10%
# Epoch 640/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.003690 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002929 | HI RMSE: 0.0241 | HI RPE: 24.49%
# Epoch 645/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.003062 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003055 | HI RMSE: 0.0214 | HI RPE: 25.85%
# Epoch 650/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.003792 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002686 | HI RMSE: 0.0200 | HI RPE: 20.99%
# Epoch 655/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002879 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002623 | HI RMSE: 0.0207 | HI RPE: 23.12%
# Epoch 660/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.003665 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002617 | HI RMSE: 0.0217 | HI RPE: 18.27%
# Epoch 665/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.003065 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003205 | HI RMSE: 0.0230 | HI RPE: 21.05%
# Epoch 670/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.003313 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002997 | HI RMSE: 0.0207 | HI RPE: 18.81%
# Epoch 675/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.003767 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003464 | HI RMSE: 0.0199 | HI RPE: 16.58%
# Epoch 680/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.003496 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002444 | HI RMSE: 0.0213 | HI RPE: 17.59%
# Epoch 685/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.003171 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002666 | HI RMSE: 0.0215 | HI RPE: 16.86%
# Epoch 690/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.003067 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002681 | HI RMSE: 0.0212 | HI RPE: 14.24%
# Epoch 695/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.003039 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003040 | HI RMSE: 0.0179 | HI RPE: 14.01%
# Epoch 700/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.003409 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003095 | HI RMSE: 0.0215 | HI RPE: 15.40%
# Epoch 705/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002672 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002801 | HI RMSE: 0.0315 | HI RPE: 12.71%
# Epoch 710/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002713 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002410 | HI RMSE: 0.0306 | HI RPE: 17.38%
# Epoch 715/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002741 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002488 | HI RMSE: 0.0234 | HI RPE: 10.19%
# Epoch 720/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002729 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003058 | HI RMSE: 0.0241 | HI RPE: 7.33%
# Epoch 725/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.003045 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002640 | HI RMSE: 0.0168 | HI RPE: 12.86%
# Epoch 730/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002556 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002977 | HI RMSE: 0.0154 | HI RPE: 7.94%
# Epoch 735/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002377 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002777 | HI RMSE: 0.0210 | HI RPE: 7.88%
# Epoch 740/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.003866 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002873 | HI RMSE: 0.0166 | HI RPE: 16.28%
# Epoch 745/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002501 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003014 | HI RMSE: 0.0254 | HI RPE: 7.24%
# Epoch 750/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.003478 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002527 | HI RMSE: 0.0274 | HI RPE: 6.88%
# Epoch 755/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.005415 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002327 | HI RMSE: 0.0316 | HI RPE: 8.80%
# Epoch 760/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002626 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002865 | HI RMSE: 0.0221 | HI RPE: 6.30%
# Epoch 765/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.003174 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003214 | HI RMSE: 0.0260 | HI RPE: 6.56%
# Epoch 770/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002994 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003245 | HI RMSE: 0.0149 | HI RPE: 7.84%
# Epoch 775/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002552 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002963 | HI RMSE: 0.0141 | HI RPE: 8.01%
# Epoch 780/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002637 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003123 | HI RMSE: 0.0129 | HI RPE: 3.71%
# Epoch 785/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002605 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002609 | HI RMSE: 0.0157 | HI RPE: 6.76%
# Epoch 790/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.003483 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003042 | HI RMSE: 0.0143 | HI RPE: 6.99%
# Epoch 795/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002887 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003478 | HI RMSE: 0.0177 | HI RPE: 4.21%
# Epoch 800/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002848 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002899 | HI RMSE: 0.0147 | HI RPE: 4.35%
# Epoch 805/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002910 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002847 | HI RMSE: 0.0200 | HI RPE: 5.19%
# Epoch 810/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002841 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002391 | HI RMSE: 0.0261 | HI RPE: 11.76%
# Epoch 815/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002618 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002942 | HI RMSE: 0.0241 | HI RPE: 11.57%
# Epoch 820/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002447 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002973 | HI RMSE: 0.0159 | HI RPE: 4.41%
# Epoch 825/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002289 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002688 | HI RMSE: 0.0143 | HI RPE: 4.95%
# Epoch 830/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002332 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002953 | HI RMSE: 0.0194 | HI RPE: 11.18%
# Epoch 835/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001894 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002473 | HI RMSE: 0.0247 | HI RPE: 8.55%
# Epoch 840/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002990 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002114 | HI RMSE: 0.0191 | HI RPE: 5.12%
# Epoch 845/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.003142 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002396 | HI RMSE: 0.0136 | HI RPE: 4.46%
# Epoch 850/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002395 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002325 | HI RMSE: 0.0146 | HI RPE: 5.08%
# Epoch 855/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002397 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002508 | HI RMSE: 0.0140 | HI RPE: 4.41%
# Epoch 860/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002084 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002900 | HI RMSE: 0.0140 | HI RPE: 3.62%
# Epoch 865/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.003029 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002035 | HI RMSE: 0.0169 | HI RPE: 5.65%
# Epoch 870/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002474 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002615 | HI RMSE: 0.0167 | HI RPE: 5.69%
# Epoch 875/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001887 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002274 | HI RMSE: 0.0126 | HI RPE: 3.66%
# Epoch 880/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002337 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002558 | HI RMSE: 0.0146 | HI RPE: 4.18%
# Epoch 885/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001910 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002249 | HI RMSE: 0.0142 | HI RPE: 2.97%
# Epoch 890/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002351 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002576 | HI RMSE: 0.0125 | HI RPE: 2.38%
# Epoch 895/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.003305 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002475 | HI RMSE: 0.0120 | HI RPE: 6.31%
# Epoch 900/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001940 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002396 | HI RMSE: 0.0195 | HI RPE: 8.94%
# Epoch 905/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001983 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.003129 | HI RMSE: 0.0181 | HI RPE: 4.65%
# Epoch 910/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002159 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002540 | HI RMSE: 0.0130 | HI RPE: 2.54%
# Epoch 915/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002130 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002328 | HI RMSE: 0.0208 | HI RPE: 4.43%
# Epoch 920/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002386 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002683 | HI RMSE: 0.0186 | HI RPE: 4.42%
# Epoch 925/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001815 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002381 | HI RMSE: 0.0124 | HI RPE: 2.71%
# Epoch 930/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002381 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002235 | HI RMSE: 0.0145 | HI RPE: 3.51%
# Epoch 935/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002255 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002440 | HI RMSE: 0.0146 | HI RPE: 4.07%
# Epoch 940/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002072 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002440 | HI RMSE: 0.0137 | HI RPE: 6.25%
# Epoch 945/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002136 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002451 | HI RMSE: 0.0132 | HI RPE: 7.39%
# Epoch 950/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002033 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002394 | HI RMSE: 0.0155 | HI RPE: 5.70%
# Epoch 955/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001968 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002472 | HI RMSE: 0.0156 | HI RPE: 3.95%
# Epoch 960/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001841 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002280 | HI RMSE: 0.0130 | HI RPE: 5.42%
# Epoch 965/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001814 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002462 | HI RMSE: 0.0118 | HI RPE: 4.99%
# Epoch 970/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001938 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002098 | HI RMSE: 0.0121 | HI RPE: 6.34%
# Epoch 975/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001456 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002273 | HI RMSE: 0.0143 | HI RPE: 6.33%
# Epoch 980/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001636 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002049 | HI RMSE: 0.0131 | HI RPE: 2.95%
# Epoch 985/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002508 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002395 | HI RMSE: 0.0188 | HI RPE: 4.54%
# Epoch 990/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002600 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002581 | HI RMSE: 0.0174 | HI RPE: 8.66%
# Epoch 995/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.006246 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002051 | HI RMSE: 0.0173 | HI RPE: 4.23%
# Epoch 1000/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.003147 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.001967 | HI RMSE: 0.0137 | HI RPE: 3.34%
# Epoch 1005/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001506 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002390 | HI RMSE: 0.0133 | HI RPE: 3.31%
# Epoch 1010/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001975 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002293 | HI RMSE: 0.0201 | HI RPE: 4.92%
# Epoch 1015/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001789 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002279 | HI RMSE: 0.0137 | HI RPE: 8.07%
# Epoch 1020/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002086 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002273 | HI RMSE: 0.0129 | HI RPE: 5.46%
# Epoch 1025/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.003064 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002599 | HI RMSE: 0.0165 | HI RPE: 4.29%
# Epoch 1030/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001652 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002359 | HI RMSE: 0.0158 | HI RPE: 3.79%
# Epoch 1035/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002716 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002598 | HI RMSE: 0.0244 | HI RPE: 9.78%
# Epoch 1040/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002029 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002349 | HI RMSE: 0.0271 | HI RPE: 5.89%
# Epoch 1045/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.003748 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002491 | HI RMSE: 0.0196 | HI RPE: 6.20%
# Epoch 1050/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002990 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002526 | HI RMSE: 0.0157 | HI RPE: 4.07%
# Epoch 1055/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.003137 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002499 | HI RMSE: 0.0123 | HI RPE: 3.21%
# Epoch 1060/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.003164 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002304 | HI RMSE: 0.0182 | HI RPE: 3.98%
# Epoch 1065/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001809 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002472 | HI RMSE: 0.0123 | HI RPE: 3.14%
# Epoch 1070/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001932 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002214 | HI RMSE: 0.0148 | HI RPE: 3.36%
# Epoch 1075/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001954 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002419 | HI RMSE: 0.0161 | HI RPE: 3.91%
# Epoch 1080/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002576 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002490 | HI RMSE: 0.0112 | HI RPE: 2.72%
# Epoch 1085/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002943 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002331 | HI RMSE: 0.0117 | HI RPE: 2.90%
# Epoch 1090/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001427 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001993 | HI RMSE: 0.0151 | HI RPE: 3.56%
# Epoch 1095/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001529 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002236 | HI RMSE: 0.0205 | HI RPE: 6.77%
# Epoch 1100/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001696 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001952 | HI RMSE: 0.0127 | HI RPE: 6.12%
# Epoch 1105/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002207 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002226 | HI RMSE: 0.0205 | HI RPE: 5.40%
# Epoch 1110/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002669 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002902 | HI RMSE: 0.0327 | HI RPE: 11.44%
# Epoch 1115/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001420 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002855 | HI RMSE: 0.0224 | HI RPE: 7.00%
# Epoch 1120/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001951 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002188 | HI RMSE: 0.0147 | HI RPE: 3.67%
# Epoch 1125/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.003661 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002671 | HI RMSE: 0.0163 | HI RPE: 3.83%
# Epoch 1130/2000 | TP (GT: 355, Used: 354) | CP Loss: 0.003658 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002194 | HI RMSE: 0.0126 | HI RPE: 3.36%
# Epoch 1135/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001785 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002638 | HI RMSE: 0.0146 | HI RPE: 4.15%
# Epoch 1140/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002052 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002199 | HI RMSE: 0.0136 | HI RPE: 3.06%
# Epoch 1145/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001353 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002180 | HI RMSE: 0.0170 | HI RPE: 4.53%
# Epoch 1150/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002095 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002233 | HI RMSE: 0.0106 | HI RPE: 3.40%
# Epoch 1155/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002024 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002245 | HI RMSE: 0.0104 | HI RPE: 2.97%
# Epoch 1160/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001415 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002185 | HI RMSE: 0.0141 | HI RPE: 3.74%
# Epoch 1165/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001533 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002362 | HI RMSE: 0.0129 | HI RPE: 3.20%
# Epoch 1170/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001711 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002079 | HI RMSE: 0.0151 | HI RPE: 3.49%
# Epoch 1175/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001839 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002261 | HI RMSE: 0.0234 | HI RPE: 9.16%
# Epoch 1180/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002053 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002234 | HI RMSE: 0.0184 | HI RPE: 7.01%
# Epoch 1185/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001515 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001948 | HI RMSE: 0.0107 | HI RPE: 2.64%
# Epoch 1190/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002406 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002148 | HI RMSE: 0.0133 | HI RPE: 3.61%
# Epoch 1195/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001727 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002154 | HI RMSE: 0.0113 | HI RPE: 3.14%
# Epoch 1200/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001471 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002026 | HI RMSE: 0.0125 | HI RPE: 3.79%
# Epoch 1205/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001573 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002071 | HI RMSE: 0.0135 | HI RPE: 5.70%
# Epoch 1210/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001736 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002215 | HI RMSE: 0.0137 | HI RPE: 5.36%
# Epoch 1215/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001255 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002479 | HI RMSE: 0.0125 | HI RPE: 3.66%
# Epoch 1220/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001674 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002166 | HI RMSE: 0.0178 | HI RPE: 5.72%
# Epoch 1225/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001254 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002184 | HI RMSE: 0.0125 | HI RPE: 5.15%
# Epoch 1230/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001562 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002194 | HI RMSE: 0.0151 | HI RPE: 5.06%
# Epoch 1235/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001316 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002513 | HI RMSE: 0.0143 | HI RPE: 3.31%
# Epoch 1240/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002182 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001856 | HI RMSE: 0.0133 | HI RPE: 3.80%
# Epoch 1245/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002615 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002001 | HI RMSE: 0.0136 | HI RPE: 3.78%
# Epoch 1250/2000 | TP (GT: 355, Used: 354) | CP Loss: 0.004002 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002643 | HI RMSE: 0.0149 | HI RPE: 5.51%
# Epoch 1255/2000 | TP (GT: 355, Used: 354) | CP Loss: 0.004569 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002240 | HI RMSE: 0.0126 | HI RPE: 3.57%
# Epoch 1260/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002272 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002140 | HI RMSE: 0.0149 | HI RPE: 4.20%
# Epoch 1265/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001611 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.001950 | HI RMSE: 0.0127 | HI RPE: 4.85%
# Epoch 1270/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001710 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002609 | HI RMSE: 0.0100 | HI RPE: 3.37%
# Epoch 1275/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001546 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002003 | HI RMSE: 0.0115 | HI RPE: 2.90%
# Epoch 1280/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001677 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002297 | HI RMSE: 0.0150 | HI RPE: 3.50%
# Epoch 1285/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001627 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002117 | HI RMSE: 0.0123 | HI RPE: 3.19%
# Epoch 1290/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001799 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001836 | HI RMSE: 0.0116 | HI RPE: 3.46%
# Epoch 1295/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001566 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002101 | HI RMSE: 0.0173 | HI RPE: 4.50%
# Epoch 1300/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001174 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002534 | HI RMSE: 0.0123 | HI RPE: 4.31%
# Epoch 1305/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001819 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002193 | HI RMSE: 0.0106 | HI RPE: 4.66%
# Epoch 1310/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001392 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002160 | HI RMSE: 0.0149 | HI RPE: 4.33%
# Epoch 1315/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001719 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002255 | HI RMSE: 0.0123 | HI RPE: 4.22%
# Epoch 1320/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001916 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002014 | HI RMSE: 0.0123 | HI RPE: 4.56%
# Epoch 1325/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002276 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002358 | HI RMSE: 0.0143 | HI RPE: 5.64%
# Epoch 1330/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001372 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002230 | HI RMSE: 0.0218 | HI RPE: 5.08%
# Epoch 1335/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002718 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001993 | HI RMSE: 0.0147 | HI RPE: 4.36%
# Epoch 1340/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001190 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002170 | HI RMSE: 0.0179 | HI RPE: 4.54%
# Epoch 1345/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001511 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002249 | HI RMSE: 0.0130 | HI RPE: 3.86%
# Epoch 1350/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001536 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002593 | HI RMSE: 0.0102 | HI RPE: 2.71%
# Epoch 1355/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001244 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002114 | HI RMSE: 0.0153 | HI RPE: 7.22%
# Epoch 1360/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001321 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002384 | HI RMSE: 0.0152 | HI RPE: 7.84%
# Epoch 1365/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001978 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002259 | HI RMSE: 0.0105 | HI RPE: 2.86%
# Epoch 1370/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001156 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001902 | HI RMSE: 0.0119 | HI RPE: 3.19%
# Epoch 1375/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001732 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001991 | HI RMSE: 0.0113 | HI RPE: 4.73%
# Epoch 1380/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001208 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002078 | HI RMSE: 0.0107 | HI RPE: 3.94%
# Epoch 1385/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002660 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002487 | HI RMSE: 0.0118 | HI RPE: 4.37%
# Epoch 1390/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002083 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002172 | HI RMSE: 0.0183 | HI RPE: 7.41%
# Epoch 1395/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001718 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002430 | HI RMSE: 0.0166 | HI RPE: 4.41%
# Epoch 1400/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001564 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002230 | HI RMSE: 0.0112 | HI RPE: 3.01%
# Epoch 1405/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001213 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002032 | HI RMSE: 0.0131 | HI RPE: 3.47%
# Epoch 1410/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001392 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002108 | HI RMSE: 0.0122 | HI RPE: 3.43%
# Epoch 1415/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001052 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001838 | HI RMSE: 0.0149 | HI RPE: 4.77%
# Epoch 1420/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.003932 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001853 | HI RMSE: 0.0176 | HI RPE: 3.45%
# Epoch 1425/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001610 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002053 | HI RMSE: 0.0142 | HI RPE: 4.54%
# Epoch 1430/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001621 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002226 | HI RMSE: 0.0172 | HI RPE: 7.72%
# Epoch 1435/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001309 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002050 | HI RMSE: 0.0137 | HI RPE: 4.66%
# Epoch 1440/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001818 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001889 | HI RMSE: 0.0133 | HI RPE: 3.27%
# Epoch 1445/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002099 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001906 | HI RMSE: 0.0134 | HI RPE: 3.67%
# Epoch 1450/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000910 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002141 | HI RMSE: 0.0164 | HI RPE: 4.01%
# Epoch 1455/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001691 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002024 | HI RMSE: 0.0124 | HI RPE: 4.77%
# Epoch 1460/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000971 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002003 | HI RMSE: 0.0114 | HI RPE: 5.00%
# Epoch 1465/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001234 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001986 | HI RMSE: 0.0130 | HI RPE: 6.19%
# Epoch 1470/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002400 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002043 | HI RMSE: 0.0105 | HI RPE: 2.74%
# Epoch 1475/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001582 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.001818 | HI RMSE: 0.0100 | HI RPE: 3.68%
# Epoch 1480/2000 | TP (GT: 355, Used: 354) | CP Loss: 0.003183 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002109 | HI RMSE: 0.0136 | HI RPE: 3.45%
# Epoch 1485/2000 | TP (GT: 355, Used: 354) | CP Loss: 0.004166 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001990 | HI RMSE: 0.0108 | HI RPE: 2.47%
# Epoch 1490/2000 | TP (GT: 355, Used: 354) | CP Loss: 0.005886 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.001940 | HI RMSE: 0.0101 | HI RPE: 2.80%
# Epoch 1495/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001891 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002269 | HI RMSE: 0.0147 | HI RPE: 7.02%
# Epoch 1500/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001286 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002129 | HI RMSE: 0.0122 | HI RPE: 3.37%
# Epoch 1505/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001561 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002087 | HI RMSE: 0.0232 | HI RPE: 7.77%
# Epoch 1510/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001313 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002559 | HI RMSE: 0.0192 | HI RPE: 4.33%
# Epoch 1515/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001219 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002025 | HI RMSE: 0.0117 | HI RPE: 5.36%
# Epoch 1520/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002178 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001875 | HI RMSE: 0.0102 | HI RPE: 3.13%
# Epoch 1525/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001647 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001933 | HI RMSE: 0.0114 | HI RPE: 6.31%
# Epoch 1530/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001204 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001736 | HI RMSE: 0.0099 | HI RPE: 3.16%
# Epoch 1535/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001056 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002084 | HI RMSE: 0.0100 | HI RPE: 3.40%
# Epoch 1540/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001181 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001695 | HI RMSE: 0.0093 | HI RPE: 2.61%
# Epoch 1545/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002200 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001880 | HI RMSE: 0.0101 | HI RPE: 4.29%
# Epoch 1550/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001340 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001789 | HI RMSE: 0.0094 | HI RPE: 5.11%
# Epoch 1555/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002275 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002089 | HI RMSE: 0.0121 | HI RPE: 6.08%
# Epoch 1560/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001072 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002094 | HI RMSE: 0.0166 | HI RPE: 6.65%
# Epoch 1565/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001097 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002187 | HI RMSE: 0.0115 | HI RPE: 5.43%
# Epoch 1570/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001162 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002148 | HI RMSE: 0.0143 | HI RPE: 3.43%
# Epoch 1575/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000932 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002236 | HI RMSE: 0.0128 | HI RPE: 7.95%
# Epoch 1580/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001802 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.001986 | HI RMSE: 0.0178 | HI RPE: 4.90%
# Epoch 1585/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000825 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002204 | HI RMSE: 0.0123 | HI RPE: 4.92%
# Epoch 1590/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001147 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001722 | HI RMSE: 0.0150 | HI RPE: 3.90%
# Epoch 1595/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001120 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001975 | HI RMSE: 0.0136 | HI RPE: 7.86%
# Epoch 1600/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001540 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001678 | HI RMSE: 0.0147 | HI RPE: 4.66%
# Epoch 1605/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001173 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001987 | HI RMSE: 0.0166 | HI RPE: 8.56%
# Epoch 1610/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001583 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001984 | HI RMSE: 0.0091 | HI RPE: 2.79%
# Epoch 1615/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.004658 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.001842 | HI RMSE: 0.0101 | HI RPE: 3.32%
# Epoch 1620/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.003670 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002130 | HI RMSE: 0.0179 | HI RPE: 7.48%
# Epoch 1625/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.003999 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002494 | HI RMSE: 0.0128 | HI RPE: 7.18%
# Epoch 1630/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001373 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002243 | HI RMSE: 0.0116 | HI RPE: 3.25%
# Epoch 1635/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000969 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001894 | HI RMSE: 0.0196 | HI RPE: 5.87%
# Epoch 1640/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001477 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002381 | HI RMSE: 0.0147 | HI RPE: 5.41%
# Epoch 1645/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001041 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002349 | HI RMSE: 0.0095 | HI RPE: 3.52%
# Epoch 1650/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000969 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002175 | HI RMSE: 0.0132 | HI RPE: 3.71%
# Epoch 1655/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000853 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002080 | HI RMSE: 0.0166 | HI RPE: 4.19%
# Epoch 1660/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001097 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002175 | HI RMSE: 0.0109 | HI RPE: 3.52%
# Epoch 1665/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001064 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002582 | HI RMSE: 0.0161 | HI RPE: 4.52%
# Epoch 1670/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001047 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002397 | HI RMSE: 0.0102 | HI RPE: 3.59%
# Epoch 1675/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001022 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001996 | HI RMSE: 0.0117 | HI RPE: 3.71%
# Epoch 1680/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001060 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002003 | HI RMSE: 0.0133 | HI RPE: 7.23%
# Epoch 1685/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001175 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.001967 | HI RMSE: 0.0163 | HI RPE: 6.55%
# Epoch 1690/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001468 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001874 | HI RMSE: 0.0100 | HI RPE: 3.22%
# Epoch 1695/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001025 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001980 | HI RMSE: 0.0135 | HI RPE: 3.81%
# Epoch 1700/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000920 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002000 | HI RMSE: 0.0140 | HI RPE: 6.23%
# Epoch 1705/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001158 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001921 | HI RMSE: 0.0150 | HI RPE: 4.95%
# Epoch 1710/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001160 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002001 | HI RMSE: 0.0101 | HI RPE: 2.86%
# Epoch 1715/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001076 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001676 | HI RMSE: 0.0143 | HI RPE: 4.17%
# Epoch 1720/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000928 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002082 | HI RMSE: 0.0100 | HI RPE: 4.33%
# Epoch 1725/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001319 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002046 | HI RMSE: 0.0148 | HI RPE: 6.26%
# Epoch 1730/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002751 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.001929 | HI RMSE: 0.0181 | HI RPE: 10.97%
# Epoch 1735/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000734 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001993 | HI RMSE: 0.0122 | HI RPE: 3.59%
# Epoch 1740/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002041 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002764 | HI RMSE: 0.0106 | HI RPE: 2.50%
# Epoch 1745/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000918 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002127 | HI RMSE: 0.0242 | HI RPE: 5.67%
# Epoch 1750/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001603 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001956 | HI RMSE: 0.0228 | HI RPE: 6.04%
# Epoch 1755/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001066 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001658 | HI RMSE: 0.0265 | HI RPE: 6.22%
# Epoch 1760/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002185 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002034 | HI RMSE: 0.0198 | HI RPE: 4.97%
# Epoch 1765/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000746 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001803 | HI RMSE: 0.0168 | HI RPE: 4.61%
# Epoch 1770/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001100 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002018 | HI RMSE: 0.0137 | HI RPE: 3.69%
# Epoch 1775/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001218 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001757 | HI RMSE: 0.0104 | HI RPE: 8.49%
# Epoch 1780/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000735 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001724 | HI RMSE: 0.0155 | HI RPE: 5.02%
# Epoch 1785/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001625 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001785 | HI RMSE: 0.0093 | HI RPE: 4.41%
# Epoch 1790/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001071 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001892 | HI RMSE: 0.0096 | HI RPE: 3.35%
# Epoch 1795/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000852 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001810 | HI RMSE: 0.0085 | HI RPE: 2.60%
# Epoch 1800/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001375 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002114 | HI RMSE: 0.0149 | HI RPE: 3.79%
# Epoch 1805/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000688 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002090 | HI RMSE: 0.0091 | HI RPE: 3.33%
# Epoch 1810/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000662 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001740 | HI RMSE: 0.0093 | HI RPE: 2.80%
# Epoch 1815/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001296 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001618 | HI RMSE: 0.0116 | HI RPE: 5.22%
# Epoch 1820/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002009 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001771 | HI RMSE: 0.0139 | HI RPE: 4.08%
# Epoch 1825/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001393 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001626 | HI RMSE: 0.0107 | HI RPE: 6.12%
# Epoch 1830/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001286 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001783 | HI RMSE: 0.0086 | HI RPE: 2.18%
# Epoch 1835/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000858 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001965 | HI RMSE: 0.0085 | HI RPE: 3.93%
# Epoch 1840/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000668 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001874 | HI RMSE: 0.0085 | HI RPE: 2.87%
# Epoch 1845/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000658 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001941 | HI RMSE: 0.0111 | HI RPE: 3.05%
# Epoch 1850/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000698 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001842 | HI RMSE: 0.0086 | HI RPE: 2.25%
# Epoch 1855/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001919 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002011 | HI RMSE: 0.0085 | HI RPE: 4.09%
# Epoch 1860/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002264 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001783 | HI RMSE: 0.0122 | HI RPE: 4.85%
# Epoch 1865/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001215 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002331 | HI RMSE: 0.0091 | HI RPE: 6.78%
# Epoch 1870/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000847 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.001775 | HI RMSE: 0.0146 | HI RPE: 3.74%
# Epoch 1875/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002763 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.001879 | HI RMSE: 0.0098 | HI RPE: 2.86%
# Epoch 1880/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.002244 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.001748 | HI RMSE: 0.0201 | HI RPE: 6.08%
# Epoch 1885/2000 | TP (GT: 355, Used: 354) | CP Loss: 0.003441 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002063 | HI RMSE: 0.0182 | HI RPE: 4.12%
# Epoch 1890/2000 | TP (GT: 355, Used: 354) | CP Loss: 0.002857 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002251 | HI RMSE: 0.0111 | HI RPE: 3.97%
# Epoch 1895/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002235 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.001764 | HI RMSE: 0.0111 | HI RPE: 5.79%
# Epoch 1900/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001154 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.001829 | HI RMSE: 0.0110 | HI RPE: 5.83%
# Epoch 1905/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000761 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.001550 | HI RMSE: 0.0086 | HI RPE: 5.91%
# Epoch 1910/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001407 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001610 | HI RMSE: 0.0083 | HI RPE: 3.29%
# Epoch 1915/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000826 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002189 | HI RMSE: 0.0079 | HI RPE: 2.70%
# Epoch 1920/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000882 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001779 | HI RMSE: 0.0077 | HI RPE: 2.78%
# Epoch 1925/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001285 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002067 | HI RMSE: 0.0089 | HI RPE: 3.66%
# Epoch 1930/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000794 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001827 | HI RMSE: 0.0090 | HI RPE: 2.95%
# Epoch 1935/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000681 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001715 | HI RMSE: 0.0086 | HI RPE: 2.10%
# Epoch 1940/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000647 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001585 | HI RMSE: 0.0160 | HI RPE: 5.55%
# Epoch 1945/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000652 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002032 | HI RMSE: 0.0091 | HI RPE: 6.12%
# Epoch 1950/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001093 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001880 | HI RMSE: 0.0234 | HI RPE: 7.48%
# Epoch 1955/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.002085 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.002437 | HI RMSE: 0.0257 | HI RPE: 8.27%
# Epoch 1960/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001969 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002437 | HI RMSE: 0.0137 | HI RPE: 3.60%
# Epoch 1965/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000621 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002091 | HI RMSE: 0.0086 | HI RPE: 2.58%
# Epoch 1970/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001227 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001700 | HI RMSE: 0.0142 | HI RPE: 5.88%
# Epoch 1975/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.001594 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001813 | HI RMSE: 0.0079 | HI RPE: 2.77%
# Epoch 1980/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000613 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001722 | HI RMSE: 0.0098 | HI RPE: 3.19%
# Epoch 1985/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000623 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001706 | HI RMSE: 0.0087 | HI RPE: 2.44%
# Epoch 1990/2000 | TP (GT: 355, Used: 356) | CP Loss: 0.001692 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001912 | HI RMSE: 0.0081 | HI RPE: 3.80%
# Epoch 1995/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.000532 | CPD F1: 0.9971 | CPD Acc: 0.9981 | HI Loss: 0.002324 | HI RMSE: 0.0119 | HI RPE: 3.99%
# Epoch 2000/2000 | TP (GT: 355, Used: 355) | CP Loss: 0.003465 | CPD F1: 1.0000 | CPD Acc: 1.0000 | HI Loss: 0.001779 | HI RMSE: 0.0118 | HI RPE: 7.70%
# ===================
#
# Time elapsed :
# 101.3915
#
# ===================
# Training completed. Best CPD F1: 1.0000, Best HI Loss: 0.001550
# Training strategy: Dynamic CPD
# Training log saved to: /home/praktikan/projects/github/DwiAnggara/ProyekRisetBearing/bearing_1/datasets/fft_dual_model_training_log.csv
# Models saved to: /home/praktikan/projects/github/DwiAnggara/ProyekRisetBearing/bearing_1/datasets/fft_dual_lstm_cp_model_best.pth and /home/praktikan/projects/github/DwiAnggara/ProyekRisetBearing/bearing_1/datasets/fft_dual_lstm_hi_model_best.pth

# %% [markdown]
# ### 3. Evalulation

# %% [markdown]
# Plot

# %%
# Create comprehensive training visualization
fig, axes = plt.subplots(3, 2, figsize=(15, 12))

# Plot 1: Loss curves
axes[0, 0].plot(training_log_df['epoch'], training_log_df['cp_loss'], label='CP Loss', color='blue', alpha=0.7)
axes[0, 0].set_xlabel('Epoch')
axes[0, 0].set_ylabel('CP Loss')
axes[0, 0].set_title('Change Point Detection Loss')
axes[0, 0].grid(True, alpha=0.3)
axes[0, 0].legend()

axes[0, 1].plot(training_log_df['epoch'], training_log_df['hi_loss'], label='HI Loss', color='red', alpha=0.7)
axes[0, 1].plot(training_log_df['epoch'], training_log_df['best_hi_loss'], label='Best HI Loss', color='darkred', linestyle='--')
axes[0, 1].set_xlabel('Epoch')
axes[0, 1].set_ylabel('HI Loss')
axes[0, 1].set_title('Health Index Loss')
axes[0, 1].grid(True, alpha=0.3)
axes[0, 1].legend()

# Plot 2: CPD metrics
axes[1, 0].plot(training_log_df['epoch'], training_log_df['cp_f1'], label='F1 Score', color='green')
axes[1, 0].plot(training_log_df['epoch'], training_log_df['best_cp_f1'], label='Best F1 Score', color='darkgreen', linestyle='--')
axes[1, 0].set_xlabel('Epoch')
axes[1, 0].set_ylabel('F1 Score')
axes[1, 0].set_title('Change Point Detection F1 Score')
axes[1, 0].grid(True, alpha=0.3)
axes[1, 0].legend()

axes[1, 1].plot(training_log_df['epoch'], training_log_df['cp_accuracy'], label='Accuracy', color='purple')
axes[1, 1].set_xlabel('Epoch')
axes[1, 1].set_ylabel('Accuracy')
axes[1, 1].set_title('Change Point Detection Accuracy')
axes[1, 1].grid(True, alpha=0.3)
axes[1, 1].legend()

# Plot 3: HI metrics and turning points
axes[2, 0].plot(training_log_df['epoch'], training_log_df['hi_rmse'], label='RMSE', color='orange')
axes[2, 0].set_xlabel('Epoch')
axes[2, 0].set_ylabel('RMSE')
axes[2, 0].set_title('Health Index RMSE')
axes[2, 0].grid(True, alpha=0.3)
axes[2, 0].legend()

# Turning point evolution
axes[2, 1].plot(training_log_df['epoch'], training_log_df['turning_point_gt'], label='Ground Truth TP', color='red', linestyle='-')
axes[2, 1].plot(training_log_df['epoch'], training_log_df['turning_point_used'], label='Used TP', color='blue', linestyle='--')
axes[2, 1].plot(training_log_df['epoch'], training_log_df['turning_point_predicted'], label='Predicted TP', color='green', linestyle=':')
axes[2, 1].set_xlabel('Epoch')
axes[2, 1].set_ylabel('Turning Point Index')
axes[2, 1].set_title('Turning Point Evolution')
axes[2, 1].grid(True, alpha=0.3)
axes[2, 1].legend()

plt.tight_layout()
plt.show()

# Print training summary
print("\n" + "="*60)
print("TRAINING SUMMARY")
print("="*60)
print(f"Total epochs trained: {len(training_log_df)}")
print(f"Final CP Loss: {training_log_df['cp_loss'].iloc[-1]:.6f}")
print(f"Final HI Loss: {training_log_df['hi_loss'].iloc[-1]:.6f}")
print(f"Best CP F1 Score: {training_log_df['best_cp_f1'].max():.4f}")
print(f"Best HI Loss: {training_log_df['best_hi_loss'].min():.6f}")
print(f"Final CP F1 Score: {training_log_df['cp_f1'].iloc[-1]:.4f}")
print(f"Final CP Accuracy: {training_log_df['cp_accuracy'].iloc[-1]:.4f}")
print(f"Final HI RMSE: {training_log_df['hi_rmse'].iloc[-1]:.4f}")
print(f"Final HI RPE: {training_log_df['hi_rpe'].iloc[-1]:.2f}%")
print("="*60)
# Out:
# ============================================================
# TRAINING SUMMARY
# ============================================================
# Total epochs trained: 400
# Final CP Loss: 0.003465
# Final HI Loss: 0.001779
# Best CP F1 Score: 1.0000
# Best HI Loss: 0.001550
# Final CP F1 Score: 1.0000
# Final CP Accuracy: 1.0000
# Final HI RMSE: 0.0118
# Final HI RPE: 7.70%
# ============================================================

# %% [markdown]
# Main

# %%
# --- EVALUATION ---
cp_model.eval()
hi_model.eval()

# Find test turning point
test_turning_point_idx = np.argmax(y_test_seq < 1.0) if np.any(y_test_seq < 1.0) else len(y_test_seq)
print(f"Test turning point index: {test_turning_point_idx}")

with torch.no_grad():
    # --- CPD Evaluation ---
    test_cp_pred_tensor = cp_model(X_test_tensor)
    test_cp_pred_prob = test_cp_pred_tensor.cpu().numpy().flatten()

    test_cp_pred = (test_cp_pred_prob > 0.5).astype(int)

    # CPD ground truth: 0 before turning point, 1 after turning point
    y_cp_test_binary = np.zeros(len(y_test_seq))
    if test_turning_point_idx < len(y_test_seq):
        y_cp_test_binary[test_turning_point_idx:] = 1

    # CPD metrics
    cp_accuracy = accuracy_score(y_cp_test_binary, test_cp_pred)
    cp_precision = precision_score(y_cp_test_binary, test_cp_pred)
    cp_recall = recall_score(y_cp_test_binary, test_cp_pred)
    cp_f1 = f1_score(y_cp_test_binary, test_cp_pred)
    cp_cm = confusion_matrix(y_cp_test_binary, test_cp_pred)


print("\n--- Change Point Detection Evaluation Metrics ---")
print(f"True turning point index: {test_turning_point_idx}")
print(f"Accuracy:  {cp_accuracy:.4f}")
print(f"Precision: {cp_precision:.4f}")
print(f"Recall:    {cp_recall:.4f}")
print(f"F1-score:  {cp_f1:.4f}")
print("Confusion Matrix:")
print(cp_cm)
print("---------------------------------------")

# Plot confusion matrix
plt.figure(figsize=(6, 4))
sns.heatmap(cp_cm, annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=["Pred: Healthy", "Pred: Degraded"], 
            yticklabels=["True: Healthy", "True: Degraded"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("CPD Confusion Matrix")
plt.tight_layout()
plt.show()

# --- HI Evaluation (only on degraded samples) ---
with torch.no_grad():
    if test_turning_point_idx < len(y_test_seq):
        X_test_degraded = X_test_tensor[test_turning_point_idx:]
        y_test_degraded = y_test_tensor[test_turning_point_idx:]
        
        if len(X_test_degraded) > 0:
            test_hi_pred_tensor = hi_model(X_test_degraded)
            test_hi_pred_degraded = test_hi_pred_tensor.cpu().numpy().flatten()
            y_hi_true_degraded = y_test_degraded.cpu().numpy().flatten()
            
            # HI metrics (only degraded region)
            mse_degraded = mean_squared_error(y_hi_true_degraded, test_hi_pred_degraded)
            rmse_degraded = rmse_score(y_hi_true_degraded, test_hi_pred_degraded)
            mae_degraded = mean_absolute_error(y_hi_true_degraded, test_hi_pred_degraded)
            r2_degraded = r2_score(y_hi_true_degraded, test_hi_pred_degraded)
            rpe_degraded = relative_prediction_error(y_hi_true_degraded, test_hi_pred_degraded)

            # Asymmetric loss (PyTorch, degraded region)
            asym_loss_degraded = asymmetric_loss_scoring_function(
                test_hi_pred_tensor, y_test_degraded
            ).item()
        else:
            mse_degraded = rmse_degraded = mae_degraded = r2_degraded = rpe_degraded = 0.0
            asym_loss_degraded = 0.0
            test_hi_pred_degraded = np.array([])
    else:
        mse_degraded = rmse_degraded = mae_degraded = r2_degraded = rpe_degraded = 0.0
        asym_loss_degraded = 0.0
        test_hi_pred_degraded = np.array([])

print("\n--- Health Index Evaluation Metrics (Degraded Region Only) ---")
print(f"Samples in degraded region: {len(test_hi_pred_degraded) if len(test_hi_pred_degraded) > 0 else 0}")
print(f"Mean Squared Error (MSE):      {mse_degraded:.6f}")
print(f"Root Mean Squared Error (RMSE):  {rmse_degraded:.6f}")
print(f"Mean Absolute Error (MAE):       {mae_degraded:.6f}")
print(f"R-squared (R²):                  {r2_degraded:.6f}")
print(f"Relative Prediction Error (RPE): {rpe_degraded:.2f}%")
print(f"Asymmetric Loss:                {asym_loss_degraded:.6f}")
print("---------------------------------------")

# Create full predictions for visualization
# Use CPD model to determine predicted turning point
predicted_turning_point_idx = np.argmax(test_cp_pred_prob > 0.5) if np.any(test_cp_pred_prob > 0.5) else len(y_test_seq)

# Construct full HI prediction: 1.0 before predicted turning point, model output after
test_hi_pred_full = np.ones(len(y_test_seq))
if predicted_turning_point_idx < len(y_test_seq) and len(test_hi_pred_degraded) > 0:
    # Adjust indices to match the degraded region
    remaining_samples = len(y_test_seq) - test_turning_point_idx
    pred_samples = min(len(test_hi_pred_degraded), remaining_samples)
    test_hi_pred_full[test_turning_point_idx:test_turning_point_idx + pred_samples] = test_hi_pred_degraded[:pred_samples]

# Visualization
plt.figure(figsize=(15, 8))

plt.subplot(2, 1, 1)
plt.plot(y_test_seq, label='True Health Index', linewidth=2, **PLOT_STYLES["HI"])
plt.plot(test_hi_pred_full, label='Predicted Health Index', **PLOT_STYLES["HI_PRED"], linewidth=2)
plt.plot(test_cp_pred_prob, label='CPD Probability', linestyle=':', alpha=0.7)
plt.axvline(x=test_turning_point_idx, **PLOT_STYLES["TP"], alpha=0.7, label=f'True Turning Point ({test_turning_point_idx})')
plt.axvline(x=predicted_turning_point_idx, **PLOT_STYLES["TP_PRED"], alpha=0.7, label=f'Predicted Turning Point ({predicted_turning_point_idx})')
plt.title('Health Index & Change Point Detection Results')
plt.xlabel('Time Steps')
plt.ylabel('Health Index / CPD Probability')
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(2, 1, 2)
plt.plot(health_index_to_rul(y_test_seq, BEARING_LIFESPAN_TIME), label='True RUL', linewidth=2, **PLOT_STYLES["HI"])
plt.plot(health_index_to_rul(test_hi_pred_full, BEARING_LIFESPAN_TIME), label='Predicted RUL', **PLOT_STYLES["HI_PRED"], linewidth=2)
plt.axvline(x=test_turning_point_idx, **PLOT_STYLES["TP"], alpha=0.7, label=f'True Turning Point ({test_turning_point_idx})')
plt.axvline(x=predicted_turning_point_idx, **PLOT_STYLES["TP_PRED"], alpha=0.7, label=f'Predicted Turning Point ({predicted_turning_point_idx})')
plt.title('RUL Prediction Results')
plt.xlabel('Time Steps')
plt.ylabel('RUL (seconds)')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Export results
results_df = pd.DataFrame({
    'time_step': np.arange(len(y_test_seq)),
    'true_health_index': y_test_seq,
    'predicted_health_index': test_hi_pred_full,
    'cpd_probability': test_cp_pred_prob,
    'cpd_binary': test_cp_pred,
    'true_cpd_binary': y_cp_test_binary,
    'predicted_rul': health_index_to_rul(test_hi_pred_full, BEARING_LIFESPAN_TIME),
})
results_path = f"{_func(MAIN_BEARING)}_dual_lstm_results.csv"
results_df.to_csv(results_path, index=False)
print(f"\nResults saved to: {results_path}")

# Export evaluation metrics
eval_metrics_df = pd.DataFrame([{
    'model': 'dual_lstm',
    'turning_point_true_idx': test_turning_point_idx,
    'turning_point_pred_idx': predicted_turning_point_idx,
    'cp_accuracy': cp_accuracy,
    'cp_precision': cp_precision,
    'cp_recall': cp_recall,
    'cp_f1': cp_f1,
    'samples_degraded': len(test_hi_pred_degraded) if len(test_hi_pred_degraded) > 0 else 0,
    'hi_mse_degraded': mse_degraded,
    'hi_rmse_degraded': rmse_degraded,
    'hi_mae_degraded': mae_degraded,
    'hi_r2_degraded': r2_degraded,
    'hi_rpe_degraded': rpe_degraded,
    'hi_asymmetric_loss_degraded': asym_loss_degraded
}])
eval_metrics_path = f"{_func(MAIN_BEARING)}_dual_lstm_eval_metrics.csv"
eval_metrics_df.to_csv(eval_metrics_path, index=False)
print(f"Evaluation metrics saved to: {eval_metrics_path}")
# Out:
# Test turning point index: 354
#
# --- Change Point Detection Evaluation Metrics ---
# True turning point index: 354
# Accuracy:  1.0000
# Precision: 1.0000
# Recall:    1.0000
# F1-score:  1.0000
# Confusion Matrix:
# [[354   0]
#  [  0 170]]
# ---------------------------------------
# --- Health Index Evaluation Metrics (Degraded Region Only) ---
# Samples in degraded region: 170
# Mean Squared Error (MSE):      0.000141
# Root Mean Squared Error (RMSE):  0.011867
# Mean Absolute Error (MAE):       0.010585
# R-squared (R²):                  0.998306
# Relative Prediction Error (RPE): 11.40%
# Asymmetric Loss:                0.000828
# ---------------------------------------
# Results saved to: /home/praktikan/projects/github/DwiAnggara/ProyekRisetBearing/bearing_1/datasets/fft_dual_lstm_results.csv
# Evaluation metrics saved to: /home/praktikan/projects/github/DwiAnggara/ProyekRisetBearing/bearing_1/datasets/fft_dual_lstm_eval_metrics.csv
